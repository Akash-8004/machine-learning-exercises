# %% [markdown]
# # Exercise
#
# 1. Use sklearn.datasets iris flower dataset to train your model using logistic regression.
# 2. You need to figure out accuracy of your model and use that to predict different samples in your test dataset. In iris dataset there are 150 samples containing following features,
#
# Sepal Length
# Sepal Width
# Petal Length
# Petal Width
# Using above 4 features you will clasify a flower in one of the three categories,
#
# Setosa
# Versicolour
# Virginica

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
dataset = load_iris()

# %%
dir(dataset)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
dataset.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset.data, dataset.target, test_size=0.2)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
len(y_test)
# Out:
# 30

# %%
model.score(X_test,y_test)
# Out:
# 0.9666666666666667

# %%
y_predict = model.predict(X_test)

# %%
print(y_test)
# Out:
# [2 2 1 2 2 2 0 1 2 2 2 2 1 1 1 2 0 1 0 0 2 2 1 0 1 1 1 0 2 2]

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_test, y_predict))
# Out:
# 0.9666666666666667
