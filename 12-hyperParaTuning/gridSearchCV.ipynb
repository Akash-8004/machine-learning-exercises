# %% [markdown]
# ## Techniques how to choose best model for our prediction
# ## also which parameer to use

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df["target"] = iris.target
df['target_names'] = df.target.apply(lambda x: iris.target_names[x])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target target_names
# 0       0       setosa
# 1       0       setosa
# 2       0       setosa
# 3       0       setosa
# 4       0       setosa

# %% [markdown]
# Traditional way of splitting dataset

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    iris.data, iris.target, test_size=0.2)

# %%
from sklearn.svm import SVC

model = SVC()
model.fit(X_train, y_train)
# Out:
# SVC()

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %% [markdown]
# *Using this it keep changing score of model
# we can't rely on this method*
#
# ### To tackle this problem we use K-fold technique

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(SVC(kernel='linear', C=10, gamma='auto'), iris.data, iris.target, cv=5)
# Out:
# array([1.        , 1.        , 0.9       , 0.96666667, 1.        ])

# %%
cross_val_score(SVC(kernel='poly', C=20, gamma='auto'), iris.data, iris.target, cv=5)
# Out:
# array([0.96666667, 0.96666667, 0.9       , 0.93333333, 1.        ])

# %%
cross_val_score(SVC(kernel='rbf', C=30, gamma='auto'), iris.data, iris.target, cv=5)
# Out:
# array([0.96666667, 1.        , 0.9       , 0.93333333, 1.        ])

# %% [markdown]
# This method is also manual.
# We can use for loop

# %%
import numpy as np

# %%
kernel = ['linear', 'poly', 'rbf']
C = [10, 20, 30, 40]
scores = {}
for kval in kernel:
    for cval in C:
        score = cross_val_score(SVC(kernel=kval, C=cval, gamma='auto'), iris.data, iris.target, cv=5)
        scores[f"score_{kval}_{cval}"]= np.average(score)

scores
# Out:
# {'score_linear_10': 0.9733333333333334,
#  'score_linear_20': 0.9666666666666666,
#  'score_linear_30': 0.96,
#  'score_linear_40': 0.96,
#  'score_poly_10': 0.9666666666666666,
#  'score_poly_20': 0.9533333333333334,
#  'score_poly_30': 0.9533333333333334,
#  'score_poly_40': 0.9533333333333334,
#  'score_rbf_10': 0.9800000000000001,
#  'score_rbf_20': 0.9666666666666668,
#  'score_rbf_30': 0.96,
#  'score_rbf_40': 0.96}

# %% [markdown]
# These technique also have some issues like if we have more param then we have to run more for loop
#
# ## Use of grid search CV

# %%
from sklearn.model_selection import GridSearchCV
clf = GridSearchCV(SVC(), {
    'C': [10, 20, 30, 40],
    'kernel': ['linear', 'poly', 'rbf']
}, cv=5)

# %%
clf.fit(iris.data, iris.target)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [10, 20, 30, 40],
#                          'kernel': ['linear', 'poly', 'rbf']})

# %%
clf.best_params_
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
clf.best_score_
# Out:
# 0.9800000000000001

# %%
results = pd.DataFrame(clf.cv_results_)

# %%
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.004268      0.007198         0.001416        0.001353       10
# 1        0.013491      0.015944         0.001613        0.001224       10
# 2        0.007195      0.010808         0.001872        0.002839       10
# 3        0.002505      0.005011         0.000000        0.000000       20
# 4        0.005174      0.006706         0.000813        0.001625       20
# 5        0.001109      0.002219         0.000000        0.000000       20
# 6        0.004207      0.006188         0.000000        0.000000       30
# 7        0.000000      0.000000         0.000000        0.000000       30
# 8        0.001005      0.000014         0.000802        0.000401       30
# 9        0.000789      0.000395         0.000420        0.000516       40
# 10       0.001397      0.000797         0.000200        0.000400       40
# 11       0.000871      0.000454         0.000665        0.000421       40
#
#    param_kernel                         params  split0_test_score  \
# 0        linear  {'C': 10, 'kernel': 'linear'}           1.000000
# 1          poly    {'C': 10, 'kernel': 'poly'}           1.000000
# 2           rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# 3        linear  {'C': 20, 'kernel': 'linear'}           1.000000
# 4          poly    {'C': 20, 'kernel': 'poly'}           1.000000
# 5           rbf     {'C': 20, 'kernel': 'rbf'}           0.966667
# 6        linear  {'C': 30, 'kernel': 'linear'}           1.000000
# 7          poly    {'C': 30, 'kernel': 'poly'}           1.000000
# 8           rbf     {'C': 30, 'kernel': 'rbf'}           0.966667
# 9        linear  {'C': 40, 'kernel': 'linear'}           1.000000
# 10         poly    {'C': 40, 'kernel': 'poly'}           1.000000
# 11          rbf     {'C': 40, 'kernel': 'rbf'}           0.966667
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 1.0           0.900000           0.966667
# 1                 1.0           0.900000           0.933333
# 2                 1.0           0.966667           0.966667
# 3                 1.0           0.900000           0.933333
# 4                 1.0           0.900000           0.933333
# 5                 1.0           0.966667           0.966667
# 6                 1.0           0.900000           0.900000
# 7                 1.0           0.900000           0.933333
# 8                 1.0           0.933333           0.966667
# 9                 1.0           0.900000           0.900000
# 10                1.0           0.900000           0.933333
# 11                1.0           0.933333           0.966667
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 1.0         0.973333        0.038873                3
# 1                 1.0         0.966667        0.042164                6
# 2                 1.0         0.980000        0.016330                1
# 3                 1.0         0.966667        0.042164                6
# 4                 1.0         0.966667        0.042164                6
# 5                 1.0         0.980000        0.016330                1
# 6                 1.0         0.960000        0.048990               11
# 7                 1.0         0.966667        0.042164                6
# 8                 1.0         0.973333        0.024944                3
# 9                 1.0         0.960000        0.048990               11
# 10                1.0         0.966667        0.042164                6
# 11                1.0         0.973333        0.024944                3

# %%
results[['param_C', 'param_kernel', 'mean_test_score', 'rank_test_score']]
# Out:
#     param_C param_kernel  mean_test_score  rank_test_score
# 0        10       linear         0.973333                3
# 1        10         poly         0.966667                6
# 2        10          rbf         0.980000                1
# 3        20       linear         0.966667                6
# 4        20         poly         0.966667                6
# 5        20          rbf         0.980000                1
# 6        30       linear         0.960000               11
# 7        30         poly         0.966667                6
# 8        30          rbf         0.973333                3
# 9        40       linear         0.960000               11
# 10       40         poly         0.966667                6
# 11       40          rbf         0.973333                3

# %% [markdown]
# All these are for best params .
# # Now for choosing best model we do hyper tunning

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
model_params = {
    'SVC': {
        'model': SVC(),
        'para': {
            'kernel': ['linear', 'poly', 'rbf'],
            'C':  [10, 20, 30, 40]
        }
    },
    'RandomForestClassifier': {
        'model': RandomForestClassifier(),
        'para':{
            "n_estimators": [50, 100],
            "max_depth": [None, 5, 10]
        }
    },
    'LogisticRegression' :{
        'model': LogisticRegression(max_iter=1000),
        'para': {
            "C": [0.1, 1, 10],
            "solver": ["liblinear", "lbfgs"]
        }
    }
}

# %%
from sklearn.model_selection import GridSearchCV
score = []
for model, mp in model_params.items():
    clf = GridSearchCV(mp['model'], mp['para'], cv=5)
    clf.fit(iris.data, iris.target)
    score.append({
    "model": model,
    "best_para" : clf.best_params_,
    "best_res": clf.best_score_
    })

# %%
best_model = pd.DataFrame(score , columns=['models', 'para', 'score'])

# %%
best_model
# Out:
#    models  para  score
# 0     NaN   NaN    NaN
# 1     NaN   NaN    NaN
# 2     NaN   NaN    NaN

# %%
score
# Out:
# [{'model': 'SVC',
#   'best_para': {'C': 10, 'kernel': 'rbf'},
#   'best_res': 0.9800000000000001},
#  {'model': 'RandomForestClassifier',
#   'best_para': {'max_depth': 5, 'n_estimators': 50},
#   'best_res': 0.9666666666666668},
#  {'model': 'LogisticRegression',
#   'best_para': {'C': 1, 'solver': 'lbfgs'},
#   'best_res': 0.9733333333333334}]
